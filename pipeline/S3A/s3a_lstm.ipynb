# %% [markdown]
# # Load Data

# %%
import pickle

# %%
with open('/project_final/orbitals.pkl', 'rb') as f:
    orbitals = pickle.load(f)

with open('/project_final/maneuvers.pkl', 'rb') as f:
    maneuvers = pickle.load(f)

# %% [markdown]
# # Check day time uniform and interpolate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime

# %%
man = maneuvers['s3a']

# %%
df = orbitals['Sentinel-3A.csv'].copy()
df = df[['Brouwer mean motion']].copy()
df.rename(columns={"Brouwer mean motion": "mean_motion"}, inplace=True)

# %%
df.index = pd.to_datetime(df.index)

# keep only year-month-day
df.index = df.index.normalize()

# %% [markdown]
# # Set up random environment

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os
from itertools import product
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
def set_seed(seed=42):
    
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

set_seed(42)

# %%
def create_sequences(data, window_size):
    sequences, targets = [], []
    for i in range(len(data) - window_size):
        sequences.append(data[i:i+window_size])
        targets.append(data[i+window_size][0])
    return np.array(sequences), np.array(targets)

# %%
def create_lstm_model(window_size, n_features, learning_rate, hidden_units, dropout_rate, fc_size):
    model = Sequential()
    model.add(Input(shape=(window_size, n_features)))
    model.add(LSTM(hidden_units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(fc_size, activation='tanh'))
    model.add(Dense(1))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mae')
    return model

# %% [markdown]
# # Split data and pre-process

# %%
data = df['mean_motion']

train_size = int(len(data) * 0.8)
train_data = data[:train_size]
val_data = data[train_size:]

train_index = df.index[:train_size]
val_index = df.index[train_size:]

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data.values.reshape(-1,1))
val_scaled = scaler.transform(val_data.values.reshape(-1,1))

train_scaled_series = pd.Series(train_scaled.flatten(), index=train_index, name='mean_motion_scaled_train')
val_scaled_series = pd.Series(val_scaled.flatten(), index=val_index, name='mean_motion_scaled_val')

# %% [markdown]
# # Tuning learning rate for models

# %%
param_grid = {
    'window_size': [3, 5, 7], # 2,3,5,7
    'learning_rate': [0.01],
    'hidden_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.3], # 0, 0.3
    'fc_size': [8, 16] # 8, 16
}

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, min_delta=1e-5)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
callbacks = [early_stop, reduce_lr]

# %%
results = []

for window_size, lr, hu, dr, fc in product(
    param_grid['window_size'],
    param_grid['learning_rate'],
    param_grid['hidden_units'],
    param_grid['dropout_rate'],
    param_grid['fc_size']
):
    set_seed(42)
    print(f"Training: window_size={window_size}, lr={lr}, hidden_units={hu}, dropout={dr}, fc_size={fc}")

    X_train, y_train = create_sequences(train_scaled, window_size)
    X_val, y_val = create_sequences(val_scaled, window_size)

    n_features = 1
    X_train = X_train.reshape((X_train.shape[0], window_size, n_features))
    X_val = X_val.reshape((X_val.shape[0], window_size, n_features))

    model = create_lstm_model(window_size, n_features,
                              learning_rate=lr,
                              hidden_units=hu,
                              dropout_rate=dr,
                              fc_size=fc)

    history = model.fit(X_train, y_train,
                        epochs=20,
                        batch_size=32,
                        validation_data=(X_val, y_val),
                        callbacks=callbacks,
                        shuffle=False,
                        verbose=0)

    y_pred_scaled = model.predict(X_val)
    y_true_scaled = y_val

    y_pred = scaler.inverse_transform(np.hstack([y_pred_scaled, np.zeros((y_pred_scaled.shape[0], n_features - 1))]))[:, 0]
    y_true = scaler.inverse_transform(np.hstack([y_true_scaled.reshape(-1, 1), np.zeros((y_true_scaled.shape[0], n_features - 1))]))[:, 0]
    
    mae = mean_absolute_error(y_true, y_pred)

    results.append({
        'window_size': window_size,
        'learning_rate': lr,
        'hidden_units': hu,
        'dropout_rate': dr,
        'fc_size': fc,
        'mae': mae
    })
    
results_df = pd.DataFrame(results)
# Out:
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Training: window_size=3, lr=0.01, hidden_units=16, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Training: window_size=3, lr=0.01, hidden_units=32, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Training: window_size=3, lr=0.01, hidden_units=64, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=5, lr=0.01, hidden_units=16, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=32, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=5, lr=0.01, hidden_units=64, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=16, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Training: window_size=7, lr=0.01, hidden_units=32, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0.1, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0.1, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0.3, fc_size=8
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Training: window_size=7, lr=0.01, hidden_units=64, dropout=0.3, fc_size=16
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
results_df.sort_values(by='mae', ascending=True).head(10)
# Out:
#     window_size  learning_rate  hidden_units  dropout_rate  fc_size  \
# 24            5           0.01            32           0.0        8
# 51            7           0.01            64           0.1       16
# 16            3           0.01            64           0.3        8
# 44            7           0.01            32           0.1        8
# 13            3           0.01            64           0.0       16
# 28            5           0.01            32           0.3        8
# 50            7           0.01            64           0.1        8
# 23            5           0.01            16           0.3       16
# 20            5           0.01            16           0.1        8
# 8             3           0.01            32           0.1        8
#
#              mae
# 24  1.489493e-08
# 51  1.502389e-08
# 16  1.525504e-08
# 44  1.543875e-08
# 13  1.564801e-08
# 28  1.583443e-08
# 50  1.588424e-08
# 23  1.595452e-08
# 20  1.598310e-08
# 8   1.601920e-08

# %%
best_idx = results_df['mae'].idxmin()
best_params = results_df.loc[best_idx]

print("\nBest hyperparameters:")
print(best_params)
# Out:
# Best hyperparameters:
# window_size      5.000000e+00
# learning_rate    1.000000e-02
# hidden_units     3.200000e+01
# dropout_rate     0.000000e+00
# fc_size          8.000000e+00
# mae              1.489493e-08
# Name: 24, dtype: float64

# %% [markdown]
# # Fit with tuned LSTM models

# %%
set_seed(42)

# %%
combined_scaled = np.vstack([train_scaled, val_scaled])

window_size = int(best_params['window_size'])
X_all, y_all = create_sequences(combined_scaled, window_size)

n_features = 1
X_all = X_all.reshape((X_all.shape[0], window_size, n_features))

# %%
final_model = create_lstm_model(
    window_size, 
    n_features,
    learning_rate=best_params['learning_rate'],
    hidden_units=int(best_params['hidden_units']),
    dropout_rate=best_params['dropout_rate'],
    fc_size=int(best_params['fc_size'])
)

# %%
final_model.fit(
    X_all, 
    y_all,
    epochs=20,
    batch_size=32,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1481
# Epoch 2/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599
# Epoch 3/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394
# Epoch 4/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477
# Epoch 5/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0285
# Epoch 6/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0289
# Epoch 7/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0319
# Epoch 8/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0300
# Epoch 9/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0324
# Epoch 10/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0298
# Epoch 11/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0345
# Epoch 12/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233
# Epoch 13/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0274
# Epoch 14/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337
# Epoch 15/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324
# Epoch 16/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0399
# Epoch 17/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0345
# Epoch 18/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0332
# Epoch 19/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0250
# Epoch 20/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0353

# %%
pred_all = final_model.predict(X_all).flatten()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
df_pred_all = pd.DataFrame({'prediction': pred_all}, index=df.index[window_size:])

y_all_series = pd.Series(y_all, index=df.index[window_size:])

lstm_pred = pd.DataFrame({
    'actual': y_all_series,
    'pred': df_pred_all['prediction']
})

print(lstm_pred.head())
# Out:
#               actual      pred
# day_time
# 2016-03-09  0.191873  0.036850
# 2016-03-10  0.191873  0.218341
# 2016-03-11  0.250808  0.216704
# 2016-03-12  0.348504  0.268935
# 2016-03-13  0.380329  0.364275

# %%
plt.figure(figsize=(12, 6))
plt.plot(lstm_pred.index, lstm_pred["actual"], label="Actual", linewidth=1)
plt.plot(lstm_pred.index, lstm_pred["pred"], label="Fitted", linewidth=1, alpha=0.8)

plt.title("LSTM In‑Sample: Actual vs Fitted")
plt.xlabel("Date")
plt.ylabel("Mean Motion")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(lstm_pred['actual'] - lstm_pred['pred'], label='Residual', color='orange')
plt.title('LSTM Residual (Full Data)')
plt.xlabel('Time Steps')
plt.ylabel('Mean Motion')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Get LSTM Residual from prediction vs true value

# %%
# xgb_pred['residual_orig'] = xgb_pred['actual_orig'] - xgb_pred['pred_orig']
lstm_pred['residual'] = lstm_pred['actual'] - lstm_pred['pred']

# %%
lstm_pred.to_csv("/project_final/result/s3a_lstm_residuals.csv", index=True)

# %% [markdown]
# # Check residuals - distribution and QQ

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

np.abs(lstm_pred['residual']).plot(ax=ax[0], title="Residuals over Time")
ax[0].set_ylabel("Residual")

lstm_pred['residual'].plot(kind='kde', ax=ax[1], title="Residual Density")

plt.tight_layout()
plt.show()

# %%
import scipy.stats as stats

# %%
lstm_res = lstm_pred['residual']

# get qq plts for res
fig, ax = plt.subplots(figsize=(6,6))
stats.probplot(lstm_res, dist="norm", plot=ax)

dots, line = ax.get_lines()
dots.set_marker('o')
dots.set_markersize(4)
dots.set_color('tab:blue')

line.set_linestyle('--')
line.set_color('tab:gray')

ax.grid(True, linestyle=':', alpha=0.5)
ax.set_title("QQ-Plot of LSTM Residuals")
ax.set_xlabel("Theoretical Quantiles")
ax.set_ylabel("Sample Residual Quantiles")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Extract anomlies

# %%
import scipy.stats as sts

# %%
# get means and var for res
mu    = lstm_res.mean()
sigma = lstm_res.std()

# %%
# p_low, p_high = sts.norm.cdf([-2.1, +2.6])
# print("percentile range", p_low, p_high)

# %%
# low, high = lstm_res.quantile([p_low, p_high])
# print("anomlies thresholds selected：", low, high)

# # get anomalies
# anomalies = lstm_res[(lstm_res < low) | (lstm_res > high)]
anomalies = lstm_res[np.abs(lstm_res) >1.232125e-01]
print("num of anomalies：", len(anomalies))
# Out:
# num of anomalies： 54

# %% [markdown]
# # Visulize result

# %%
manoeuvre_dates = pd.to_datetime(man['median_day_time']).dt.date
manoeuvre_dates = pd.to_datetime(manoeuvre_dates)
manoeuvre_dates = manoeuvre_dates[manoeuvre_dates.isin(df.index)]

# %%
plt.figure(figsize=(14, 5))

# # 1) plt actual
# plt.plot(arima_pred.index, 
#          arima_pred['actual'], 
#          label='Mean Motion (actual)', 
#          color='C0', 
#          alpha=0.8)

# 1) plt -residuals
plt.plot(lstm_pred.index, 
         lstm_pred['residual'], 
         label='Mean Motion (residuals = actual - pred)', 
         color='C0', 
         alpha=0.8)

# 2) plt man
for dt in manoeuvre_dates:
    plt.axvline(x=dt,
                color='gray',
                linestyle='--',
                linewidth=1,
                alpha=0.7)
    
# 3) plt anomalies
plt.scatter(
    anomalies.index,
    lstm_pred.loc[anomalies.index, 'residual'],
    color='red',
    marker='x',
    s=50,
    label='Outliers (percentile)'
)

plt.title("Mean Motion with Detected Outliers & Manoeuvre Events")
plt.xlabel("Date")
plt.ylabel("Mean Motion")
plt.grid(True, linestyle=':', alpha=0.5)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# get multi-cols plts
start, end = lstm_pred.index.min(), lstm_pred.index.max()
knots = pd.date_range(start, end, periods=5)
intervals = list(zip(knots[:-1], knots[1:]))

fig, axes = plt.subplots(4, 1, figsize=(12, 16), sharey=True)

for ax, (seg_start, seg_end) in zip(axes, intervals):
    segment = lstm_pred.loc[seg_start:seg_end]
    
    # actual
    ax.plot(
        segment.index, segment['actual'],
        label='Actual', color='#1f77b4', alpha=0.8, linewidth=1.0
    )
    # plt fitted
    ax.plot(
        segment.index, segment['pred'],
        label='Fitted', color='#ff7f0e', alpha=0.8, linewidth=1.0
    )
    
    # # plt -residuals
    # plt.plot(arima_pred.index, 
	# 		arima_pred['residual'], 
	# 		label='Mean Motion (residuals = actual - pred)', 
	# 		color='C0', 
	# 		alpha=0.8)
    
    # 3) plt anomalies
    idx1 = anomalies.loc[seg_start:seg_end].index
    ax.scatter(
        idx1,
        segment.loc[idx1, 'actual'],
        color='red', 
        marker='x',
        alpha = 0.75,
        s=45,
        label='Anomaly'
    )
    
    # 4) plt man
    for dt in manoeuvre_dates:
        if seg_start <= dt <= seg_end:
            ax.axvline(
                x=dt, color='#aaaaaa',
                linestyle='--', linewidth=1.2, alpha=1.0
            )
    
    # tight layout
    ax.set_xlim(seg_start, seg_end)
    # ax.grid(True, linestyle=':', alpha=0.5)
    ax.set_title(f"{seg_start.date()} → {seg_end.date()}", fontsize=10)
    ax.tick_params(axis='x', rotation=30)
    
    if ax is axes[0]:
        ax.legend(loc='upper left')

fig.suptitle(
    "Mean Motion & Fitted Values with Maneuver Events and Anomalies",
    y=1.02, fontsize=12
)
plt.tight_layout()
plt.show()

# %%
# residuals

fig, axes = plt.subplots(4, 1, figsize=(12, 16), sharey=True)

for ax, (seg_start, seg_end) in zip(axes, intervals):
    segment = lstm_pred.loc[seg_start:seg_end]
    
    ax.plot(
        segment.index, segment['residual'],
        label='Residuals (actual − pred)',
        color='C0', alpha=0.8, linewidth=1.0
    )

    idx1 = anomalies.loc[seg_start:seg_end].index
    ax.scatter(
        idx1, segment.loc[idx1, 'residual'],
        color='red', marker='x', s=50, alpha=0.8,
        label='Anomaly'
    )
    
    first = True
    for dt in manoeuvre_dates:
        if seg_start <= dt <= seg_end:
            ax.axvline(
                x=dt, color='gray', linestyle='--',
                linewidth=1.2, alpha=0.7,
                label='Maneuver' if first else None
            )
            first = False
    
    ax.set_xlim(seg_start, seg_end)
    ax.set_title(f"{seg_start.date()} → {seg_end.date()}", fontsize=10)
    ax.tick_params(axis='x', rotation=30)
    if ax is axes[0]:
        ax.legend(loc='upper left')

fig.suptitle(
    "Residuals with Detected Anomalies & Maneuver Events",
    y=1.02, fontsize=12
)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Record num of man and anomlies

# %%
# records num of anomlies and man
man_df   = man.copy()             # man
anom_idx = anomalies.index        # outliers index

man_days  = pd.to_datetime(man_df['median_day_time']).dt.normalize()
anom_days = anom_idx.normalize()

anom_set = set(anom_days)

# check deteced in +- n days range
n = 3 

matched_manoeuvres = []
unmatched_manoeuvres = []

for d in man_days:
    window = set(d + pd.to_timedelta(offset, unit='D') for offset in range(-n, n+1))
    
    if window & anom_set:
        matched_manoeuvres.append(d)
    else:
        unmatched_manoeuvres.append(d)

summary = pd.DataFrame({
    "category": [
        "total_manoeuvres",
        "total_anomalies",
        f"manoeuvres_matched_within_±{n}d",
        f"manoeuvres_unmatched_within_±{n}d"
    ],
    "count": [
        len(man_days),
        len(anom_days),
        len(matched_manoeuvres),
        len(unmatched_manoeuvres)
    ]
})

summary
# Out:
#                           category  count
# 0                 total_manoeuvres     64
# 1                  total_anomalies     54
# 2    manoeuvres_matched_within_±3d     51
# 3  manoeuvres_unmatched_within_±3d     13

# %%
# summary.to_csv("result/s3a_lstm_result.csv", index=False)
